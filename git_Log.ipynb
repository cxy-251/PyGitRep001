# %% [markdown]
# # 0 命令汇总
# ``` shell
# git init
# git add README.md
# git commit -m "Initial commit with README"
# git config user.name "Your Name"
# git config user.email "your-email@example.com"
# git remote add origin https://github.com/your-username/my-github-repo.git
# git branch -M main
# git push -u origin main
#
# git add git_Log.ipynb
# git commit -m "add the gitLog for backup"
# git reset --soft HEAD~1
# git commit -m "add the gitLog for backup"
# # 重启ide要重新remoteGitHub
# git remote set-url origin https://github.com/cxy-251/PyGitRep001.git
# git push -u origin main
#
# git commit -am "change file git_Log"
# git push -u origin main
#
# ```
# ---

# %% [markdown]
# # 1 git init后新建第一个文件并提交到github

# %%
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git add .\README.md
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> tree .git
卷 OS 的文件夹 PATH 列表
卷序列号为 0000009F 54F6:5371
C:\02PROGRAMMER\02PROJ\PYVSCODE\PYGITREP001\.GIT
├─hooks
├─info
├─objects
│  ├─dc
│  ├─info
│  └─pack
└─refs
    ├─heads
    └─tags
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> dir .git

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001\.git

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
d----            2024/9/1    10:56                hooks
d----            2024/9/1    10:56                info
d----            2024/9/1    11:14                objects
d----            2024/9/1    10:56                refs
-a---            2024/9/1    11:08            180 config
-a---            2024/9/1    10:56             73 description
-a---            2024/9/1    10:56             23 HEAD
-a---            2024/9/1    11:14            104 index

(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git commit -m "Initial commit with README"
[master (root-commit) 1a5622a] Initial commit with README
 1 file changed, 1 insertion(+)
 create mode 100644 README.md
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git remote add origin https://github.com/cxy-251/PyGitRep001.git
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git branch -M main
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git push -u origin main
info: please complete authentication in your browser...
Enumerating objects: 3, done.
Counting objects: 100% (3/3), done.
Writing objects: 100% (3/3), 251 bytes | 251.00 KiB/s, done.
Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
To https://github.com/cxy-251/PyGitRep001.git
 * [new branch]      main -> main
branch 'main' set up to track 'origin/main'.
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> dir .git

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001\.git

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
d----            2024/9/1    10:56                hooks
d----            2024/9/1    10:56                info
d----            2024/9/1    11:18                logs
d----            2024/9/1    11:18                objects
d----            2024/9/1    11:22                refs
-a---            2024/9/1    11:18             27 COMMIT_EDITMSG
-a---            2024/9/1    11:22            351 config
-a---            2024/9/1    10:56             73 description
-a---            2024/9/1    11:21             21 HEAD
-a---            2024/9/1    11:18            137 index

(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> ls .\.git\objects\

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001\.git\objects

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
d----            2024/9/1    11:18                1a
d----            2024/9/1    11:18                23
d----            2024/9/1    11:14                dc
d----            2024/9/1    10:56                info
d----            2024/9/1    10:56                pack

(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> ls .\.git\objects\dc\

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001\.git\objects\dc

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
-ar--            2024/9/1    11:14             43 78888dbbce9c3fcc659165ad24bf81794d4059      

(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git cat-file -t dc7888
blob
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git cat-file -p dc7888
# Welcome to my PyGitRep001(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> 
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git cat-file -p dc7888
# Welcome to my PyGitRep001(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> 
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> ls .\.git\objects\    

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001\.git\objects

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
d----            2024/9/1    11:18                1a
d----            2024/9/1    11:18                23
d----            2024/9/1    11:14                dc
d----            2024/9/1    10:56                info
d----            2024/9/1    10:56                pack

(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> ls .\.git\objects\23

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001\.git\objects\23

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
-ar--            2024/9/1    11:18             54 6c525e62c7ad52aee9723e0273c24da5c06012      

(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git cat-file -p 236c52
100644 blob dc78888dbbce9c3fcc659165ad24bf81794d4059    README.md
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> ls .\.git\objects\1a

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001\.git\objects\1a

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
-ar--            2024/9/1    11:18            138 5622a72f1df5cde621a99289a60a8bc7fca349      

(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git cat-file -p la5622
fatal: Not a valid object name la5622
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git cat-file -p 1a5622
tree 236c525e62c7ad52aee9723e0273c24da5c06012
author cxy-251 <1439838736@qq.com> 1725160684 +0800
committer cxy-251 <1439838736@qq.com> 1725160684 +0800

Initial commit with README
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001>

# %% [markdown]
# # 2 终端无法连接github
# > 尝试使用ssh连接，无果
# >> 如果终端重启过，需要重新 **remote**

# %%
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> ssh-keygen -t rsa -b 4096 -C "1439838736@qq.com"
Generating public/private rsa key pair.
Enter file in which to save the key (C:\Users\14398/.ssh/id_rsa): ./.ssh/id_rsa
Enter passphrase (empty for no passphrase): 
Enter same passphrase again: 
Your identification has been saved in ./.ssh/id_rsa.
Your public key has been saved in ./.ssh/id_rsa.pub.
The key fingerprint is:
SHA256:c/ugZbfFEOyLN/DZeFbgPIHIX/TRs7l/9b4HNms4lwY 1439838736@qq.com
The key's randomart image is:
+---[RSA 4096]----+
|              ...|
|         . o o oo|
|          o + + =|
|           o = = |
|        S o + + o|
|         o =EB++.|
|          * O+*=+|
|         + =o** =|
|        .   o= o=|
+----[SHA256]-----+

# 密钥已经删掉了

(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git remote set-url origin git@github.com:cxy-251/PyGitRep001.git
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> ssh -T git@github.com
git@github.com: Permission denied (publickey).
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> ssh -T git@github.com
git@github.com: Permission denied (publickey).
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git push -u origin main
git@github.com: Permission denied (publickey).
fatal: Could not read from remote repository.

Please make sure you have the correct access rights
and the repository exists.
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git remote set-url origin https://github.com/cxy-251/PyGitRep001.git
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git push -u origin main
Enumerating objects: 4, done.
Counting objects: 100% (4/4), done.
Delta compression using up to 8 threads
Compressing objects: 100% (3/3), done.
Writing objects: 100% (3/3), 1.72 KiB | 1.72 MiB/s, done.
Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
To https://github.com/cxy-251/PyGitRep001.git
   1a5622a..f86c953  main -> main
branch 'main' set up to track 'origin/main'.

# %% [markdown]
# # 3 修改已添加的文件

# %%
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git commit -am "change file git_Log"
warning: in the working copy of 'git_Log.ipynb', LF will be replaced by CRLF the next time Git touches it
[main 81f29be] change file git_Log
 1 file changed, 88 insertions(+), 2 deletions(-)
(base) PS C:\02Programmer\02Proj\PyVSCode\PyGitRep001> git push -u origin main
Enumerating objects: 5, done.
Counting objects: 100% (5/5), done.
Delta compression using up to 8 threads
Compressing objects: 100% (3/3), done.
Writing objects: 100% (3/3), 1.30 KiB | 1.30 MiB/s, done.
Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
remote: Resolving deltas: 100% (1/1), completed with 1 local object.
To https://github.com/cxy-251/PyGitRep001.git
   f86c953..81f29be  main -> main
branch 'main' set up to track 'origin/main'.

# %% [markdown]
# # 4 添加文件夹也一样
# > 又一次遇到无法连接的问题，啥也不干等一会就行

# %%
╰─ git push -u origin main
fatal: unable to access 'https://github.com/cxy-251/PyGitRep001.git/': Failed to connect to github.com port 443 after 21087 ms: Couldn't connect to server

╭─    🏠   PyGitRep001   main ↑1  ~1 | RAM: 13/16GB ⌛  21.162s ⏰  20:40:36 
╰─ git push -u origin main
Enumerating objects: 5, done.
Counting objects: 100% (5/5), done.
Delta compression using up to 8 threads
Compressing objects: 100% (3/3), done.
Writing objects: 100% (4/4), 3.12 KiB | 3.12 MiB/s, done.
Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
To https://github.com/cxy-251/PyGitRep001.git
   81f29be..7fc7bdf  main -> main
branch 'main' set up to track 'origin/main'.

# %% [markdown]
# # 添加Tools文件夹

# %%
PowerShell 7.4.4

   A new PowerShell stable release is available: v7.4.5
   Upgrade now, or check out the release page at:
     https://aka.ms/PowerShell-Release?tag=v7.4.5

Loading personal and system profiles took 7456ms.
╭─    🏠   02Programmer                                | RAM: 9/16GB ⏰  08:34:57 
╰─ cd C:\02Programmer\02Proj\PyVSCode\PyGitRep001\
╭─    🏠   PyGitRep001   main ≡  ?1 ~1            | RAM: 13/16GB ⏰  01:39:28 
╰─ ls

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
d----            2024/9/1    20:30                DataStructuresAndAlgorithms
d----            2024/9/7     1:03                Tools
-a---            2024/9/1    22:08          13906 git_Log.ipynb
-a---            2024/9/1    11:14             27 README.md


╭─    🏠   PyGitRep001   main ≡  ?1 ~1            | RAM: 13/16GB ⏰  01:39:29 
╰─ git add .\Tools\
warning: in the working copy of 'Tools/dealWithString.ipynb', LF will be replaced by CRLF the next time Git touches it

╭─    🏠   PyGitRep001   main ≡  ~1 |  +1        | RAM: 13/16GB ⏰  01:39:50 
╰─ git commit -m "Push The First Tools For Valid PhoneNumber Check"
[main d82bf3e] Push The First Tools For Valid PhoneNumber Check
 1 file changed, 484 insertions(+)
 create mode 100644 Tools/dealWithString.ipynb

╭─    🏠   PyGitRep001   main ↑1  ~1              | RAM: 13/16GB ⏰  01:41:11 
╰─ git push -u origin main
Enumerating objects: 5, done.
Counting objects: 100% (5/5), done.
Delta compression using up to 8 threads
Compressing objects: 100% (3/3), done.
Writing objects: 100% (4/4), 2.89 KiB | 2.89 MiB/s, done.
Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
remote: Resolving deltas: 100% (1/1), completed with 1 local object.
To https://github.com/cxy-251/PyGitRep001.git
   7fc7bdf..d82bf3e  main -> main
branch 'main' set up to track 'origin/main'.

# %% [markdown]
# # 添加.gitignore文件并排除.git文件夹，然后git add .

# %%
╭─    🏠   PyGitRep001   main ≡  ~1  | RAM: 13/16GB ⌛  2.533s ⏰  01:41:25 
╰─ ls

    Directory: C:\02Programmer\02Proj\PyVSCode\PyGitRep001

Mode                 LastWriteTime         Length Name
----                 -------------         ------ ----
d----            2024/9/8    22:13                DataStructuresAndAlgorithms
d----            2024/9/7     1:03                Tools
-a---            2024/9/8    23:07              5 .gitignore
-a---            2024/9/7     1:42          16753 git_Log.ipynb
-a---            2024/9/1    11:14             27 README.md

╭─    🏠   PyGitRep001   main ≡  ?3 ~3                         | RAM: 13/16GB ⏰  23:08:16 
╰─ git add .
warning: in the working copy of 'DataStructuresAndAlgorithms/Linear.ipynb', LF will be replaced by CRLF the next time Git touches it
warning: in the working copy of 'Tools/dealWithString.ipynb', LF will be replaced by CRLF the next time Git touches it
warning: in the working copy of 'git_Log.ipynb', LF will be replaced by CRLF the next time Git touches it
warning: in the working copy of 'DataStructuresAndAlgorithms/NonLinear.ipynb', LF will be replaced by CRLF the next time Git touches it

╭─    🏠   PyGitRep001   main ≡  +48 ~3            | RAM: 13/16GB ⌛  514ms ⏰  23:08:22 
╰─ git commit -m "Update Linear.ipynb Deque List Stack. Add NewCoder cases solved by GPT4o"
[main ba5de0b] Update Linear.ipynb Deque List Stack. Add NewCoder cases solved by GPT4o
 51 files changed, 2310 insertions(+), 11 deletions(-)
 create mode 100644 .gitignore
 create mode 100644 DataStructuresAndAlgorithms/NonLinear.ipynb
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-13-47.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-17-27.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-19-12.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-21-23.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-22-51.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-24-17.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-25-23.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-26-29.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-28-12.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-28-48.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-29-37.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-31-01.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-31-44.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-33-13.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-34-02.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-34-52.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-35-47.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-36-06.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-37-25.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-37-46.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-38-40.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-39-07.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-39-47.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-40-26.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-45-26.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-45-57.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-46-57.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-47-31.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-48-33.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-49-02.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-49-49.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-50-23.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-51-13.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-51-51.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-52-52.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-53-54.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-54-40.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-55-26.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-56-05.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-56-42.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-57-06.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-58-01.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-58-18.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-59-03.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-22-59-18.png
 create mode 100644 DataStructuresAndAlgorithms/img/2024-09-08-23-00-51.png

╭─    🏠   PyGitRep001   main ↑1  ~1               | RAM: 13/16GB ⌛  446ms ⏰  23:11:24 
╰─ git push -u origin main
fatal: unable to access 'https://github.com/cxy-251/PyGitRep001.git/': Recv failure: Connection was reset

╭─    🏠   PyGitRep001   main ↑1  ~1             | RAM: 13/16GB ⌛  32.574s ⏰  23:12:23 
╰─ git remote set-url origin https://github.com/cxy-251/PyGitRep001.git

╭─    🏠   PyGitRep001   main ↑1  ~1                           | RAM: 13/16GB ⏰  23:14:23 
╰─ git push -u origin main
fatal: unable to access 'https://github.com/cxy-251/PyGitRep001.git/': Failed to connect to github.com port 443 after 21090 ms: Couldn't connect to server

╭─    🏠   PyGitRep001   main ↑1  ~1             | RAM: 13/16GB ⌛  21.167s ⏰  23:14:46 
╰─ git push -u origin main
fatal: unable to access 'https://github.com/cxy-251/PyGitRep001.git/': Failed to connect to github.com port 443 after 21050 ms: Couldn't connect to server

╭─    🏠   PyGitRep001   main ↑1  ~1             | RAM: 13/16GB ⌛  21.123s ⏰  23:16:05 
╰─ git push -u origin main
Enumerating objects: 62, done.
Counting objects: 100% (62/62), done.
Delta compression using up to 8 threads
Compressing objects: 100% (54/54), done.
Writing objects: 100% (56/56), 3.36 MiB | 1.18 MiB/s, done.
Total 56 (delta 2), reused 0 (delta 0), pack-reused 0
remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
To https://github.com/cxy-251/PyGitRep001.git
   d82bf3e..ba5de0b  main -> main
branch 'main' set up to track 'origin/main'.

╭─    🏠   PyGitRep001   main ≡  ?2 ~1            | RAM: 13/16GB ⌛  5.521s ⏰  00:32:50 
╰─

# %% [markdown]
# # hhh

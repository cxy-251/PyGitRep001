# %% [markdown]
# ```bash
# winget install FilesCommunity.Files
# ```
# win10安裝win11的文件夾，可以加標籤頁，甚至win11的文件夾還要好用

# %% [markdown]
# ```bash
# pip install ?
# ```
# require.txt = [
#     jupyterlab,
# ]

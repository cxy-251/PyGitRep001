# %% [markdown]
# ## 树
# https://www.bilibili.com/video/BV1VC4y1x7uv?p=59&vd_source=c8a5e3184b42acd26c4aeac082b04bb0

# %% [markdown]
# ### 树的实现

# %% [markdown]
# #### 嵌套列表

# %% [markdown]
# #### 链表

# %% [markdown]
# ### 树的应用 表达式解析
